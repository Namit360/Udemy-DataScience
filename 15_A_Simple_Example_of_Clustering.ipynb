# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.cluster import KMeans

# %% [markdown]
# ## Load the data

# %%
data = pd.read_csv('Countries-exercise.csv')
data
# Out:
#              name   Longitude   Latitude
# 0           Aruba  -69.982677  12.520880
# 1     Afghanistan   66.004734  33.835231
# 2          Angola   17.537368 -12.293361
# 3        Anguilla  -63.064989  18.223959
# 4         Albania   20.049834  41.142450
# ..            ...         ...        ...
# 236         Samoa -172.164851 -13.753243
# 237         Yemen   47.586762  15.909280
# 238  South Africa   25.083901 -29.000341
# 239        Zambia   27.774759 -13.458242
# 240      Zimbabwe   29.851441 -19.004204
#
# [241 rows x 3 columns]

# %% [markdown]
# ## Plot the data

# %%
plt.scatter(data['Longitude'], data['Latitude'])
plt.xlim(-180,180)
plt.ylim(-90, 90)
plt.show()

# %% [markdown]
# ## Select the features

# %%
x = data.iloc[:,1:3]
x
# Out:
#       Longitude   Latitude
# 0    -69.982677  12.520880
# 1     66.004734  33.835231
# 2     17.537368 -12.293361
# 3    -63.064989  18.223959
# 4     20.049834  41.142450
# ..          ...        ...
# 236 -172.164851 -13.753243
# 237   47.586762  15.909280
# 238   25.083901 -29.000341
# 239   27.774759 -13.458242
# 240   29.851441 -19.004204
#
# [241 rows x 2 columns]

# %% [markdown]
# ## Clustering

# %%
kmeans = KMeans(7) # 7 indicates no of clusters

# %%
kmeans.fit(x)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=7)

# %% [markdown]
# ## Clustering Results

# %%
identified_clusters = kmeans.fit_predict(x)
identified_clusters
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# array([0, 2, 1, 0, 3, 3, 3, 2, 0, 2, 4, 1, 5, 1, 0, 5, 3, 2, 1, 3, 6, 6,
#        2, 3, 2, 0, 0, 3, 0, 3, 0, 0, 0, 0, 0, 5, 2, 1, 6, 3, 0, 2, 6, 6,
#        1, 6, 4, 0, 1, 6, 0, 0, 0, 0, 3, 3, 3, 3, 1, 0, 3, 0, 6, 0, 3, 1,
#        3, 3, 1, 3, 5, 0, 3, 3, 5, 6, 3, 3, 3, 6, 6, 6, 6, 6, 3, 0, 3, 0,
#        5, 0, 5, 1, 0, 3, 0, 3, 5, 3, 2, 5, 1, 3, 2, 2, 3, 3, 3, 0, 3, 3,
#        5, 2, 2, 1, 2, 5, 0, 0, 5, 3, 2, 2, 3, 6, 3, 0, 3, 2, 1, 3, 3, 3,
#        5, 0, 6, 3, 3, 1, 2, 0, 5, 3, 6, 3, 2, 3, 2, 5, 1, 6, 0, 1, 1, 5,
#        1, 5, 6, 5, 6, 0, 4, 3, 3, 2, 5, 5, 2, 2, 0, 4, 0, 5, 5, 5, 3, 0,
#        5, 3, 0, 3, 4, 2, 3, 2, 1, 6, 2, 1, 1, 6, 5, 6, 6, 5, 6, 0, 3, 1,
#        1, 0, 3, 6, 0, 3, 3, 3, 1, 0, 1, 3, 0, 6, 6, 2, 2, 2, 5, 4, 0, 3,
#        3, 5, 1, 1, 3, 0, 0, 2, 3, 0, 0, 0, 0, 5, 5, 4, 4, 2, 1, 1, 1],
#       dtype=int32)

# %%
data_cluster = data.copy()
data_cluster['Clusters'] = identified_clusters
data_cluster
# Out:
#              name   Longitude   Latitude  Clusters
# 0           Aruba  -69.982677  12.520880         0
# 1     Afghanistan   66.004734  33.835231         2
# 2          Angola   17.537368 -12.293361         1
# 3        Anguilla  -63.064989  18.223959         0
# 4         Albania   20.049834  41.142450         3
# ..            ...         ...        ...       ...
# 236         Samoa -172.164851 -13.753243         4
# 237         Yemen   47.586762  15.909280         2
# 238  South Africa   25.083901 -29.000341         1
# 239        Zambia   27.774759 -13.458242         1
# 240      Zimbabwe   29.851441 -19.004204         1
#
# [241 rows x 4 columns]

# %%
plt.scatter(data['Longitude'], data['Latitude'],c=data_cluster['Clusters'], cmap = 'rainbow')
plt.xlim(-180,180)
plt.ylim(-90, 90)
plt.show()
